# %%
(ls_file <- list.files("digitiser_csv", full.names = TRUE))
# Out:
#  [1] "digitiser_csv/005-941.csv" "digitiser_csv/005-942.csv"
#  [3] "digitiser_csv/005-943.csv" "digitiser_csv/005-944.csv"
#  [5] "digitiser_csv/005-945.csv" "digitiser_csv/005-946.csv"
#  [7] "digitiser_csv/005-947.csv" "digitiser_csv/005-948.csv"
#  [9] "digitiser_csv/005-949.csv" "digitiser_csv/005-950.csv"
# [11] "digitiser_csv/005-951.csv" "digitiser_csv/005-952.csv"
# [13] "digitiser_csv/005-953.csv" "digitiser_csv/005-954.csv"
# [15] "digitiser_csv/005-955.csv" "digitiser_csv/005-956.csv"
# [17] "digitiser_csv/005-957.csv" "digitiser_csv/005-958.csv"
# [19] "digitiser_csv/005-959.csv" "digitiser_csv/005-960.csv"
# [21] "digitiser_csv/005-961.csv" "digitiser_csv/005-962.csv"
# [23] "digitiser_csv/005-963.csv" "digitiser_csv/005-964.csv"
# [25] "digitiser_csv/005-965.csv" "digitiser_csv/005-966.csv"
# [27] "digitiser_csv/005-967.csv"

# %%
get_digitiser <- function(csv_file){

    read.csv(csv_file) |>
    
 
}

# %%
get_digitiser(ls_file[1]) |>  head()
# Out:
#   sample_id Particle.Diameter..µm. Volume.Frequency.Percent
# 1 T1SG1     0.4493990              0.00000
# 2 T1SG1     0.4760276              0.00744
# 3 T1SG1     0.5042340              0.02804
# 4 T1SG1     0.5341117              0.06480
# 5 T1SG1     0.5657598              0.11766
# 6 T1SG1     0.5992832              0.18324
#   Particle.Diameter..µm..1 Cumulative.Finer.Volume.Percent
# 1 0.4366486                0.00000
# 2 0.4625217                0.00000
# 3 0.4899278                0.00744
# 4 0.5189579                0.03548
# 5 0.5497080                0.10028
# 6 0.5822803                0.21794

# %%
#  approx(x = df$diameter, y = df$cumulative, xout = cutoff)$y

# %%
#http://localhost:8889/lab?token=f7562502286cdae70c1998a8885098375951a20cf48620a3

# %%
#do.call(rbind, 
lapply( read.csv(ls_file[1])
# Out:
#     sample_id Particle.Diameter..µm. Volume.Frequency.Percent
# 1   T1SG1     0.4493990              0.00000
# 2   T1SG1     0.4760276              0.00744
# 3   T1SG1     0.5042340              0.02804
# 4   T1SG1     0.5341117              0.06480
# 5   T1SG1     0.5657598              0.11766
# 6   T1SG1     0.5992832              0.18324
# 7   T1SG1     0.6347930              0.25504
# 8   T1SG1     0.6724068              0.32445
# 9   T1SG1     0.7122494              0.38208
# 10  T1SG1     0.7544528              0.41978
# 11  T1SG1     0.7991570              0.43267
# 12  T1SG1     0.8465100              0.42061
# 13  T1SG1     0.8966689              0.38892
# 14  T1SG1     0.9497998              0.34764
# 15  T1SG1     1.0060790              0.30955
# 16  T1SG1     1.0656930              0.28708
# 17  T1SG1     1.1288392              0.28923
# 18  T1SG1     1.1957272              0.31836
# 19  T1SG1     1.2665785              0.36904
# ...
